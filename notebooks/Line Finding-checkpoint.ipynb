# %%
from astropy.modeling import models, Fittable1DModel, Parameter
from astropy.modeling.fitting import LevMarLSQFitter
import astropy.units as u
import astropy.constants as const
from astropy.io import fits

from spectacle.core.spectrum import Spectrum1D
from spectacle.modeling.custom import Masker
from spectacle.modeling.fitters import MCMCFitter
from spectacle.analysis.line_finder import LineFinder
from spectacle.io.registries import line_registry

import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
wavelength = np.linspace(1200, 1235, 1000) * u.Angstrom
velocity = np.linspace(-400, 800, 1000) * u.Unit("km/s")

dispersion = velocity

with fits.open("/home/nmearl/Downloads/hlsp_misty_foggie_halo008508_rd0020_i021.8_dx44.99_v2_los.fits") as hdulist:
    y = hdulist[2].data['tau']
    dispersion = hdulist[2].data['wavelength'] * u.Unit('Angstrom')
    print(hdulist[2].header)
# Out:
# XTENSION= 'BINTABLE'           / binary table extension                         BITPIX  =                    8 / array data type                                NAXIS   =                    2 / number of array dimensions                     NAXIS1  =                   40 / length of dimension 1                          NAXIS2  =               174095 / length of dimension 2                          PCOUNT  =                    0 / number of group parameters                     GCOUNT  =                    1 / number of groups                               TFIELDS =                   10 / number of table fields                         LINENAME= 'H I 1216'                                                            RESTWAVE=              1215.67 / Angstroms                                      F_VALUE =                0.416                                                  GAMMA   =          469000000.0                                                  HIERARCH SIM_TAU_HDENS = -9999.0                                                HIERARCH SIM_TAU_TEMP = -9999.0                                                 HIERARCH SIM_TAU_METAL = -9999.0                                                HIERARCH TOT_COLUMN = 15.95733428606506 / log cm^-2                             FITLCEN1=              1215.67 / Angstrom, center of component, observed wavelenFITLCEN3=              1215.67 / Angstrom, center of component, observed wavelenNCOMP   =                    3 / number of fitted components                    FITLCEN2=              1215.67 / Angstrom, center of component, observed wavelenFITEW1  =    1.319886154124078 / Angstrom, total equivalent width               FITEW3  =    1.319886154124078 / Angstrom, total equivalent width               FITEW2  =    1.319886154124078 / Angstrom, total equivalent width               FITB2   =    31.44020741434527 / km s^-1                                        FITCOL1 =    14.92256581023864 / log cm^-2                                      FITCOL2 =    14.10190729666413 / log cm^-2                                      FITB1   =    54.85815085442138 / km s^-1                                        FITCOL3 =    13.91249356380703 / log cm^-2                                      FITB3   =    42.73978529382342 / km s^-1                                        EXTNAME = 'H I 1216'           / extension name                                 TTYPE1  = 'redshift'                                                            TFORM1  = 'E       '                                                            TTYPE2  = 'wavelength'                                                          TFORM2  = 'E       '                                                            TUNIT2  = 'Angstrom'                                                            TTYPE3  = 'tau     '                                                            TFORM3  = 'E       '                                                            TTYPE4  = 'flux    '                                                            TFORM4  = 'E       '                                                            TTYPE5  = 'sim_tau_ray'                                                         TFORM5  = 'E       '                                                            TTYPE6  = 'sim_column_density'                                                  TFORM6  = 'E       '                                                            TTYPE7  = 'sim_lambda_obs'                                                      TFORM7  = 'E       '                                                            TTYPE8  = 'sim_thermal_b'                                                       TFORM8  = 'E       '                                                            TTYPE9  = 'sim_delta_lambda'                                                    TFORM9  = 'E       '                                                            TTYPE10 = 'sim_thermal_width'                                                    ...

# %%
spectrum = Spectrum1D(ion='hi1215', redshift=0.0)
spectrum.add_line(v_doppler=9e6 * u.Unit('cm/s'))
spectrum.add_line(v_doppler=3.5e6 * u.Unit('cm/s'), delta_v=290 * u.Unit('km/s'))

# y = spectrum.optical_depth(dispersion)
# Out:
# INFO:root:Found line with name 'HI1216' from given name 'hi1215'.
# INFO:root:Default continuum set to a Linear1D model.

# %%
f, ax = plt.subplots()

ax.plot(dispersion, y)
# Out:
# <div id='0eed433e-db42-4cdd-9d82-88f5f82b25ec'></div>

# %%
spec_mod = LineFinder(dispersion, y, ion='hi1215').fit()
# Out:
# INFO:root:Found line with name 'HI1216' from given name 'hi1215'.
# INFO:root:Relative tolerance: 0.010000, Absolute Tolerance: 0.000100
# INFO:root:Threshold: 0.100000, Minimum Distance: 30.000000
# INFO:root:Found 1 peaks.
# INFO:root:Default continuum set to a Linear1D model.
# Parameter('amplitude_L', value=244.87284890362815) 244.878082275
# Gamma: 1.21575e-05 cm
# 1215.6701 Angstrom
# 797667682.0744823 cm / s
# Velocity: 7.97668e+08 cm / s
# Column density: 8.46997e-11 cm2 kg / s2
# ---------------------------------------------------------------------------
# UnitConversionError                       Traceback (most recent call last)
# <ipython-input-6-10504f9a3944> in <module>()
# ----> 1 spec_mod = LineFinder(dispersion, y, ion='hi1215').fit()
#
# ~/projects/spectacle/spectacle/analysis/line_finder.py in fit(self, *args, **kwargs)
#     213     def fit(self, *args, **kwargs):
#     214         fitter = LevMarLSQFitter(*args, **kwargs)
# --> 215         fit_finder_model = fitter(self, self._x, self._y, self._y)
#     216
#     217         return fit_finder_model.result_model
#
# ~/miniconda3/envs/spec_env/lib/python3.6/site-packages/astropy/modeling/fitting.py in wrapper(self, model, x, y, z, equivalencies, **kwargs)
#     165                     model_new = func(self, model, xdata, ydata, **kwargs)
#     166                 else:
# --> 167                     model_new = func(self, model, xdata, ydata, zdata, **kwargs)
#     168
#     169                 # And finally we add back units to the parameters
#
# ~/miniconda3/envs/spec_env/lib/python3.6/site-packages/astropy/modeling/fitting.py in __call__(self, model, x, y, z, weights, maxiter, acc, epsilon, estimate_jacobian)
#     693             self.objective_function, init_values, args=farg, Dfun=dfunc,
#     694             col_deriv=model_copy.col_fit_deriv, maxfev=maxiter, epsfcn=epsilon,
# --> 695             xtol=acc, full_output=True)
#     696         _fitter_to_model_params(model_copy, fitparams)
#     697         self.fit_info.update(dinfo)
#
# ~/miniconda3/envs/spec_env/lib/python3.6/site-packages/scipy/optimize/minpack.py in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     375     if not isinstance(args, tuple):
#     376         args = (args,)
# --> 377     shape, dtype = _check_func('leastsq', 'func', func, x0, args, n)
#     378     m = shape[0]
#     379     if n > m:
#
# ~/miniconda3/envs/spec_env/lib/python3.6/site-packages/scipy/optimize/minpack.py in _check_func(checker, argname, thefunc, x0, args, numinputs, output_shape)
#      24 def _check_func(checker, argname, thefunc, x0, args, numinputs,
#      25                 output_shape=None):
# ---> 26     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#      27     if (output_shape is not None) and (shape(res) != output_shape):
#      28         if (output_shape[0] != 1):
#
# ~/miniconda3/envs/spec_env/lib/python3.6/site-packages/astropy/modeling/fitting.py in objective_function(self, fps, *args)
#     636         meas = args[-1]
#     637         if weights is None:
# --> 638             return np.ravel(model(*args[2: -1]) - meas)
#     639         else:
#     640             return np.ravel(weights * (model(*args[2: -1]) - meas))
#
# ~/miniconda3/envs/spec_env/lib/python3.6/site-packages/astropy/modeling/core.py in __call__(self, x, y, model_set_axis, with_bounding_box, fill_value, equivalencies)
#     399                                      ('with_bounding_box', False),
#     400                                      ('fill_value', np.nan),
# --> 401                                      ('equivalencies', None)])
#     402
#     403             # The following makes it look like __call__ was defined in the class
#
# ~/miniconda3/envs/spec_env/lib/python3.6/site-packages/astropy/modeling/core.py in __call__(self, *inputs, **kwargs)
#     380             def __call__(self, *inputs, **kwargs):
#     381                 """Evaluate this model on the supplied inputs."""
# --> 382                 return super(cls, self).__call__(*inputs, **kwargs)
#     383
#     384             # When called, models can take two optional keyword arguments:
#
# ~/miniconda3/envs/spec_env/lib/python3.6/site-packages/astropy/modeling/core.py in __call__(self, x, y, model_set_axis, with_bounding_box, fill_value, equivalencies)
#     399                                      ('with_bounding_box', False),
#     400                                      ('fill_value', np.nan),
# --> 401                                      ('equivalencies', None)])
#     402
#     403             # The following makes it look like __call__ was defined in the class
#
# ~/miniconda3/envs/spec_env/lib/python3.6/site-packages/astropy/modeling/core.py in __call__(self, *inputs, **kwargs)
#     380             def __call__(self, *inputs, **kwargs):
#     381                 """Evaluate this model on the supplied inputs."""
# --> 382                 return super(cls, self).__call__(*inputs, **kwargs)
#     383
#     384             # When called, models can take two optional keyword arguments:
#
# ~/miniconda3/envs/spec_env/lib/python3.6/site-packages/astropy/modeling/core.py in __call__(self, *inputs, **kwargs)
#     783                     outputs = [np.asarray(r) for r in result]
#     784         else:
# --> 785             outputs = self.evaluate(*chain(inputs, parameters))
#     786         if self.n_outputs == 1:
#     787             outputs = (outputs,)
#
# ~/projects/spectacle/spectacle/analysis/line_finder.py in evaluate(self, x, y, center, redshift, threshold, min_distance, rel_tol, abs_tol, width)
#     190         self._result_model = getattr(spectrum, self._data_type)
#     191
# --> 192         return self._result_model(x)
#     193
#     194     def _parameter_units_for_data_units(self, input_units, output_units):
#
# ~/miniconda3/envs/spec_env/lib/python3.6/site-packages/astropy/modeling/core.py in __call__(self, x, model_set_axis, with_bounding_box, fill_value, equivalencies)
#     399                                      ('with_bounding_box', False),
#     400                                      ('fill_value', np.nan),
# --> 401                                      ('equivalencies', None)])
#     402
#     403             # The following makes it look like __call__ was defined in the class
#
# ~/miniconda3/envs/spec_env/lib/python3.6/site-packages/astropy/modeling/core.py in __call__(self, *inputs, **kwargs)
#     380             def __call__(self, *inputs, **kwargs):
#     381                 """Evaluate this model on the supplied inputs."""
# --> 382                 return super(cls, self).__call__(*inputs, **kwargs)
#     383
#     384             # When called, models can take two optional keyword arguments:
#
# ~/miniconda3/envs/spec_env/lib/python3.6/site-packages/astropy/modeling/core.py in __call__(self, x, model_set_axis, with_bounding_box, fill_value, equivalencies)
#     399                                      ('with_bounding_box', False),
#     400                                      ('fill_value', np.nan),
# --> 401                                      ('equivalencies', None)])
#     402
#     403             # The following makes it look like __call__ was defined in the class
#
# ~/miniconda3/envs/spec_env/lib/python3.6/site-packages/astropy/modeling/core.py in __call__(self, *inputs, **kwargs)
#     380             def __call__(self, *inputs, **kwargs):
#     381                 """Evaluate this model on the supplied inputs."""
# --> 382                 return super(cls, self).__call__(*inputs, **kwargs)
#     383
#     384             # When called, models can take two optional keyword arguments:
#
# ~/miniconda3/envs/spec_env/lib/python3.6/site-packages/astropy/modeling/core.py in __call__(self, *inputs, **kwargs)
#     783                     outputs = [np.asarray(r) for r in result]
#     784         else:
# --> 785             outputs = self.evaluate(*chain(inputs, parameters))
#     786         if self.n_outputs == 1:
#     787             outputs = (outputs,)
#
# ~/miniconda3/envs/spec_env/lib/python3.6/site-packages/astropy/modeling/core.py in evaluate(self, *args)
#    2842     @sharedmethod
#    2843     def evaluate(self, *args):
# -> 2844         return self.__class__.evaluate(*args)
#    2845
#    2846     # TODO: The way this works is highly inefficient--the inverse is created by
#
# ~/miniconda3/envs/spec_env/lib/python3.6/site-packages/astropy/modeling/core.py in evaluate(cls, *args)
#    2312         inputs = args[:cls.n_inputs]
#    2313         params = iter(args[cls.n_inputs:])
# -> 2314         result = cls._evaluate(inputs, params)
#    2315         if cls.n_outputs == 1:
#    2316             return result[0]
#
# ~/miniconda3/envs/spec_env/lib/python3.6/site-packages/astropy/modeling/core.py in <lambda>(inputs, params)
#    2137     #
#    2138     # and similarly for g
# -> 2139     return (lambda inputs, params: g[0](f[0](inputs, params), params),
#    2140             f[1], g[2])
#    2141
#
# ~/miniconda3/envs/spec_env/lib/python3.6/site-packages/astropy/modeling/core.py in <lambda>(inputs, params)
#    2137     #
#    2138     # and similarly for g
# -> 2139     return (lambda inputs, params: g[0](f[0](inputs, params), params),
#    2140             f[1], g[2])
#    2141
#
# ~/miniconda3/envs/spec_env/lib/python3.6/site-packages/astropy/modeling/core.py in <lambda>(inputs, params)
#    2754             if n_outputs == 1:
#    2755                 f = lambda inputs, params: \
# -> 2756                     (evaluate(*chain(inputs, islice(params, n_params))),)
#    2757             else:
#    2758                 f = lambda inputs, params: \
#
# ~/projects/spectacle/spectacle/modeling/profiles.py in evaluate(self, x, lambda_0, f_value, gamma, v_doppler, column_density, delta_v, delta_lambda)
#     124         lambda_0 = u.Quantity(lambda_0, 'Angstrom')
#     125         v_doppler = u.Quantity(v_doppler, 'cm/s')
# --> 126         column_density = u.Quantity(column_density, '1/cm2')
#     127         delta_lambda = u.Quantity(delta_lambda, 'Angstrom')
#     128         delta_v = u.Quantity(delta_v, 'cm/s')
#
# ~/miniconda3/envs/spec_env/lib/python3.6/site-packages/astropy/units/quantity.py in __new__(cls, value, unit, dtype, copy, order, subok, ndmin)
#     291         if isinstance(value, Quantity):
#     292             if unit is not None and unit is not value.unit:
# --> 293                 value = value.to(unit)
#     294                 # the above already makes a copy (with float dtype)
#     295                 copy = False
#
# ~/miniconda3/envs/spec_env/lib/python3.6/site-packages/astropy/units/quantity.py in to(self, unit, equivalencies)
#     842         # and don't want to slow down this method (esp. the scalar case).
#     843         unit = Unit(unit)
# --> 844         return self._new_view(self._to_value(unit, equivalencies), unit)
#     845
#     846     def to_value(self, unit=None, equivalencies=[]):
#
# ~/miniconda3/envs/spec_env/lib/python3.6/site-packages/astropy/units/quantity.py in _to_value(self, unit, equivalencies)
#     814             equivalencies = self._equivalencies
#     815         return self.unit.to(unit, self.view(np.ndarray),
# --> 816                             equivalencies=equivalencies)
#     817
#     818     def to(self, unit, equivalencies=[]):
#
# ~/miniconda3/envs/spec_env/lib/python3.6/site-packages/astropy/units/core.py in to(self, other, value, equivalencies)
#     975             If units are inconsistent
#     976         """
# --> 977         return self._get_converter(other, equivalencies=equivalencies)(value)
#     978
#     979     def in_units(self, other, value=1.0, equivalencies=[]):
#
# ~/miniconda3/envs/spec_env/lib/python3.6/site-packages/astropy/units/core.py in _get_converter(self, other, equivalencies)
#     909                             pass
#     910
# --> 911             raise exc
#     912
#     913     def _to(self, other):
#
# ~/miniconda3/envs/spec_env/lib/python3.6/site-packages/astropy/units/core.py in _get_converter(self, other, equivalencies)
#     895         try:
#     896             return self._apply_equivalencies(
# --> 897                 self, other, self._normalize_equivalencies(equivalencies))
#     898         except UnitsError as exc:
#     899             # Last hope: maybe other knows how to do it?
#
# ~/miniconda3/envs/spec_env/lib/python3.6/site-packages/astropy/units/core.py in _apply_equivalencies(self, unit, other, equivalencies)
#     879         raise UnitConversionError(
#     880             "{0} and {1} are not convertible".format(
# --> 881                 unit_str, other_str))
#     882
#     883     def _get_converter(self, other, equivalencies=[]):
#
# UnitConversionError: 'cm2 kg / s2' (energy) and '1 / cm2' are not convertible

# %%
print(fit_finder_model(dispersion, y))
print(fit_finder_model.result_model)

f, ax = plt.subplots()

ax.plot(dispersion, spectrum.optical_depth(dispersion))
ax.plot(dispersion, fit_finder_model.result_model(dispersion))
